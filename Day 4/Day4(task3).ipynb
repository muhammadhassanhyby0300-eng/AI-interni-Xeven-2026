# %%
#Research work Day 4 task(3)
## Question :
##Ask ChatGPT:Explain logical operators with real-world examples'
##Ask Gemini: What is operator precedence in Python and why does it matter?
##Ask Claude: Best practices for type conversion and error handling in Python
 
 ###  Chat GPT:

Logical operators in Python are used to combine multiple conditions and return True or False.
The three main logical operators are:
1. AND operator (and)

👉 Returns True only if both conditions are True

2. OR operator (or)

👉 Returns True if at least one condition is True

3. NOT operator (not)

👉 Reverses the result (True → False, False → True)

###Gemini:

Operator precedence in Python determines the order in which
different operations are performed in an expression. Think 
of it like a set of rules that tells Python which part of a 
math problem to solve first.


### Claude:

1. Use try/except for all conversions
Never assume a conversion will succeed.

2. Catch specific exceptions, not broad ones
Use ValueError and TypeError

3. Validate with isinstance() before converting

4. Return a default value instead of crashing

5. Prefer explicit over implicit conversion
Don't rely on Python auto-converting. 

6. Add meaningful error messages
